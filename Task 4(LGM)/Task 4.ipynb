# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from matplotlib import dates as mpl_dates

# %% [markdown]
# ## Mount the drive and import the datset

# %%
#let's mount the google drive for import the dtaset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv("/content/drive/MyDrive/LGM 4/DATA.csv")
df.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  08-10-2018  208.00  222.25  206.85  216.00  215.15               4642146
# 1  05-10-2018  217.00  218.60  205.90  210.25  209.20               3519515
# 2  04-10-2018  223.50  227.80  216.15  217.25  218.20               1728786
# 3  03-10-2018  230.00  237.50  225.75  226.45  227.60               1708590
# 4  01-10-2018  234.55  234.60  221.05  230.30  230.90               1534749
#
#    Turnover (Lacs)
# 0         10062.83
# 1          7407.06
# 2          3815.79
# 3          3960.27
# 4          3486.05

# %%
df.tail()
# Out:
#             Date    Open    High     Low   Last   Close  Total Trade Quantity  \
# 1230  14-10-2013  160.85  161.45  157.70  159.3  159.45               1281419
# 1231  11-10-2013  161.15  163.45  159.00  159.8  160.05               1880046
# 1232  10-10-2013  156.00  160.80  155.85  160.3  160.15               3124853
# 1233  09-10-2013  155.70  158.20  154.15  155.3  155.55               2049580
# 1234  08-10-2013  157.00  157.80  155.20  155.8  155.80               1720413
#
#       Turnover (Lacs)
# 1230          2039.09
# 1231          3030.76
# 1232          4978.80
# 1233          3204.49
# 1234          2688.94

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1235 entries, 0 to 1234
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  1235 non-null   object
#  1   Open                  1235 non-null   float64
#  2   High                  1235 non-null   float64
#  3   Low                   1235 non-null   float64
#  4   Last                  1235 non-null   float64
#  5   Close                 1235 non-null   float64
#  6   Total Trade Quantity  1235 non-null   int64
#  7   Turnover (Lacs)       1235 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 77.3+ KB

# %%
df.shape
# Out:
# (1235, 8)

# %%
df.describe()
# Out:
#               Open         High          Low         Last        Close  \
# count  1235.000000  1235.000000  1235.000000  1235.000000  1235.000000
# mean    168.954858   171.429069   166.402308   168.736356   168.731053
# std      51.499145    52.436761    50.542919    51.587384    51.544928
# min     103.000000   104.600000   100.000000   102.600000   102.650000
# 25%     137.550000   138.925000   135.250000   137.175000   137.225000
# 50%     151.500000   153.250000   149.500000   151.200000   151.100000
# 75%     169.000000   172.325000   166.700000   169.100000   169.500000
# max     327.700000   328.750000   321.650000   325.950000   325.750000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          1.235000e+03      1235.000000
# mean           2.604151e+06      4843.166502
# std            2.277028e+06      5348.919832
# min            1.001800e+05       128.040000
# 25%            1.284482e+06      1801.035000
# 50%            1.964885e+06      3068.510000
# 75%            3.095788e+06      5852.600000
# max            2.919102e+07     55755.080000

# %% [markdown]
# ## Cheking null value

# %%
df.isnull().sum()
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Last', 'Close', 'Total Trade Quantity',
#        'Turnover (Lacs)'],
#       dtype='object')

# %% [markdown]
# ## Checking the varriable distribution type

# %%
features = df[['Open',  'Close','Total Trade Quantity',
       'Turnover (Lacs)']]
sns.pairplot(features, hue='Turnover (Lacs)')

# %%
df1=df.reset_index()['Close']
df1
# Out:
# 0       215.15
# 1       209.20
# 2       218.20
# 3       227.60
# 4       230.90
#          ...
# 1230    159.45
# 1231    160.05
# 1232    160.15
# 1233    155.55
# 1234    155.80
# Name: Close, Length: 1235, dtype: float64

# %%
df.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  08-10-2018  208.00  222.25  206.85  216.00  215.15               4642146
# 1  05-10-2018  217.00  218.60  205.90  210.25  209.20               3519515
# 2  04-10-2018  223.50  227.80  216.15  217.25  218.20               1728786
# 3  03-10-2018  230.00  237.50  225.75  226.45  227.60               1708590
# 4  01-10-2018  234.55  234.60  221.05  230.30  230.90               1534749
#
#    Turnover (Lacs)
# 0         10062.83
# 1          7407.06
# 2          3815.79
# 3          3960.27
# 4          3486.05

# %% [markdown]
# ## Converting the Date from object to Datetime format

# %%
df['Date']=pd.to_datetime(df["Date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1235 entries, 0 to 1234
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  1235 non-null   datetime64[ns]
#  1   Open                  1235 non-null   float64
#  2   High                  1235 non-null   float64
#  3   Low                   1235 non-null   float64
#  4   Last                  1235 non-null   float64
#  5   Close                 1235 non-null   float64
#  6   Total Trade Quantity  1235 non-null   int64
#  7   Turnover (Lacs)       1235 non-null   float64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 77.3 KB

# %%
df.head()
# Out:
#         Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0 2018-08-10  208.00  222.25  206.85  216.00  215.15               4642146
# 1 2018-05-10  217.00  218.60  205.90  210.25  209.20               3519515
# 2 2018-04-10  223.50  227.80  216.15  217.25  218.20               1728786
# 3 2018-03-10  230.00  237.50  225.75  226.45  227.60               1708590
# 4 2018-01-10  234.55  234.60  221.05  230.30  230.90               1534749
#
#    Turnover (Lacs)
# 0         10062.83
# 1          7407.06
# 2          3815.79
# 3          3960.27
# 4          3486.05

# %% [markdown]
# # Plotting the varriable

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.plot_date(df['Date'],df["Open"], linestyle="solid",color='red')
plt.xlabel("year")
plt.ylabel("Open_share_price")
plt.subplot(1,2,2)
plt.plot_date(df['Date'],df["Low"], linestyle="solid",color='pink')
plt.xlabel("year")
plt.ylabel("Low_share_price")
# Out:
# Text(0, 0.5, 'Low_share_price')

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.plot_date(df['Date'],df["High"], linestyle="solid",color='Blue')
plt.xlabel("year")
plt.ylabel("High_share_price")
plt.subplot(1,2,2)
plt.plot_date(df['Date'],df["Last"], linestyle="solid",color='pink')
plt.xlabel("year")
plt.ylabel("Last_share_price")
# Out:
# Text(0, 0.5, 'Last_share_price')

# %% [markdown]
# Due to almost similar nature of variable pattern ;select close as our predicting independent variable

# %%
df1=df.reset_index()["Close"]

# %%
df1
# Out:
# 0       215.15
# 1       209.20
# 2       218.20
# 3       227.60
# 4       230.90
#          ...
# 1230    159.45
# 1231    160.05
# 1232    160.15
# 1233    155.55
# 1234    155.80
# Name: Close, Length: 1235, dtype: float64

# %%
plt.plot(df1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
df1
# Out:
# array([[0.50425818],
#        [0.47758853],
#        [0.51792918],
#        ...,
#        [0.25773196],
#        [0.2371134 ],
#        [0.23823398]])

# %% [markdown]
# Training of data

# %%
training_size=int(len(df1)*0.65)
test_size=len(df1)-training_size
train_data,test_data=df1[0:training_size,:],df1[training_size:len(df1),:1]

# %%
training_size,test_size
# Out:
# (802, 433)

# %%
import numpy
def create_dataset(dataset,time_step=1):
    dataX, dataY=[],[]
    for i in range(len(dataset)-time_step-1):
        a= dataset[i:(i+time_step),0]
        dataX.append(a)
        dataY.append(dataset[i +time_step,0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
time_step=100
X_train,y_train=create_dataset(train_data, time_step)
X_test,y_test = create_dataset(test_data, time_step)

# %%
print(X_train)
# Out:
# [[0.50425818 0.47758853 0.51792918 ... 0.64926042 0.62057373 0.62752129]
#  [0.47758853 0.51792918 0.56006275 ... 0.62057373 0.62752129 0.6869117 ]
#  [0.51792918 0.56006275 0.57485433 ... 0.62752129 0.6869117  0.82855222]
#  ...
#  [0.13693411 0.14634693 0.1322277  ... 0.15620798 0.17525773 0.16293142]
#  [0.14634693 0.1322277  0.14500224 ... 0.17525773 0.16293142 0.15844913]
#  [0.1322277  0.14500224 0.14657104 ... 0.16293142 0.15844913 0.15912147]]

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (701, 100)
# (701,)
# (None, None)

# %%
print(X_test.shape), print(y_test.shape)
# Out:
# (332, 100)
# (332,)
# (None, None)

# %%
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test=X_test.reshape(X_test.shape[0],X_test.shape[1],1)

# %% [markdown]
# Importing the tensor flow for neurala network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %% [markdown]
# Neural network formation

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1)) 
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Training the model

# %%
model.fit(X_train,y_train, validation_data=(X_test,y_test), epochs=100,batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 9s 317ms/step - loss: 0.0594 - val_loss: 0.0017
# Epoch 2/100
# 11/11 [==============================] - 2s 192ms/step - loss: 0.0090 - val_loss: 0.0014
# Epoch 3/100
# 11/11 [==============================] - 2s 197ms/step - loss: 0.0041 - val_loss: 0.0029
# Epoch 4/100
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0030 - val_loss: 0.0010
# Epoch 5/100
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0026 - val_loss: 9.2901e-04
# Epoch 6/100
# 11/11 [==============================] - 2s 198ms/step - loss: 0.0025 - val_loss: 9.7446e-04
# Epoch 7/100
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0024 - val_loss: 0.0016
# Epoch 8/100
# 11/11 [==============================] - 3s 302ms/step - loss: 0.0024 - val_loss: 9.3720e-04
# Epoch 9/100
# 11/11 [==============================] - 3s 238ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 10/100
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 11/100
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0020 - val_loss: 0.0010
# Epoch 12/100
# 11/11 [==============================] - 3s 266ms/step - loss: 0.0020 - val_loss: 8.7888e-04
# Epoch 13/100
# 11/11 [==============================] - 3s 271ms/step - loss: 0.0020 - val_loss: 8.0764e-04
# Epoch 14/100
# 11/11 [==============================] - 2s 190ms/step - loss: 0.0019 - val_loss: 9.6338e-04
# Epoch 15/100
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0018 - val_loss: 8.0627e-04
# Epoch 16/100
# 11/11 [==============================] - 2s 197ms/step - loss: 0.0019 - val_loss: 0.0010
# Epoch 17/100
# 11/11 [==============================] - 2s 192ms/step - loss: 0.0019 - val_loss: 0.0010
# Epoch 18/100
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0018 - val_loss: 8.6095e-04
# Epoch 19/100
# 11/11 [==============================] - 4s 381ms/step - loss: 0.0016 - val_loss: 9.9270e-04
# Epoch 20/100
# 11/11 [==============================] - 4s 355ms/step - loss: 0.0017 - val_loss: 7.5485e-04
# Epoch 21/100
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0016 - val_loss: 9.9234e-04
# Epoch 22/100
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0017 - val_loss: 8.9469e-04
# Epoch 23/100
# 11/11 [==============================] - 4s 349ms/step - loss: 0.0017 - val_loss: 7.7489e-04
# Epoch 24/100
# 11/11 [==============================] - 3s 276ms/step - loss: 0.0015 - val_loss: 7.7244e-04
# Epoch 25/100
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0015 - val_loss: 7.0702e-04
# Epoch 26/100
# 11/11 [==============================] - 2s 192ms/step - loss: 0.0015 - val_loss: 7.1694e-04
# Epoch 27/100
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0015 - val_loss: 8.5199e-04
# Epoch 28/100
# 11/11 [==============================] - 2s 192ms/step - loss: 0.0014 - val_loss: 7.1102e-04
# Epoch 29/100
# 11/11 [==============================] - 3s 289ms/step - loss: 0.0018 - val_loss: 7.9732e-04
# Epoch 30/100
# 11/11 [==============================] - 3s 261ms/step - loss: 0.0017 - val_loss: 0.0010
# Epoch 31/100
# 11/11 [==============================] - 2s 192ms/step - loss: 0.0014 - val_loss: 8.0280e-04
# Epoch 32/100
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0013 - val_loss: 6.9155e-04
# Epoch 33/100
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0013 - val_loss: 7.2948e-04
# Epoch 34/100
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0013 - val_loss: 8.0730e-04
# Epoch 35/100
# 11/11 [==============================] - 2s 192ms/step - loss: 0.0013 - val_loss: 6.9241e-04
# Epoch 36/100
# 11/11 [==============================] - 3s 309ms/step - loss: 0.0012 - val_loss: 7.1636e-04
# Epoch 37/100
# 11/11 [==============================] - 3s 252ms/step - loss: 0.0012 - val_loss: 7.6080e-04
# Epoch 38/100
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0012 - val_loss: 7.8584e-04
# Epoch 39/100
# 11/11 [==============================] - 2s 191ms/step - loss: 0.0012 - val_loss: 6.2303e-04
# Epoch 40/100
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0012 - val_loss: 8.3002e-04
# Epoch 41/100
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0011 - val_loss: 9.6768e-04
# Epoch 42/100
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0012 - val_loss: 6.2643e-04
# Epoch 43/100
# 11/11 [==============================] - 2s 192ms/step - loss: 0.0012 - val_loss: 6.0040e-04
# Epoch 44/100
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0011 - val_loss: 8.2332e-04
# Epoch 45/100
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0011 - val_loss: 7.8929e-04
# Epoch 46/100
# 11/11 [==============================] - 2s 200ms/step - loss: 0.0011 - val_loss: 5.8632e-04
# Epoch 47/100
# 11/11 [==============================] - 3s 274ms/step - loss: 0.0010 - val_loss: 6.3600e-04
# Epoch 48/100
# 11/11 [==============================] - 4s 391ms/step - loss: 0.0010 - val_loss: 5.7808e-04
# Epoch 49/100
# 11/11 [==============================] - 5s 491ms/step - loss: 0.0011 - val_loss: 9.2783e-04
# Epoch 50/100
# 11/11 [==============================] - 4s 324ms/step - loss: 0.0010 - val_loss: 5.7295e-04
# Epoch 51/100
# 11/11 [==============================] - 2s 195ms/step - loss: 9.9311e-04 - val_loss: 0.0010
# Epoch 52/100
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0011 - val_loss: 6.8222e-04
# Epoch 53/100
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0012 - val_loss: 5.4826e-04
# Epoch 54/100
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0010 - val_loss: 6.8321e-04
# Epoch 55/100
# 11/11 [==============================] - 3s 276ms/step - loss: 9.6913e-04 - val_loss: 5.7619e-04
# Epoch 56/100
# 11/11 [==============================] - 3s 259ms/step - loss: 0.0012 - val_loss: 6.9463e-04
# Epoch 57/100
# 11/11 [==============================] - 4s 367ms/step - loss: 0.0010 - val_loss: 6.4945e-04
# Epoch 58/100
# 11/11 [==============================] - 3s 250ms/step - loss: 9.4283e-04 - val_loss: 5.7558e-04
# Epoch 59/100
# 11/11 [==============================] - 2s 197ms/step - loss: 0.0010 - val_loss: 6.5342e-04
# Epoch 60/100
# 11/11 [==============================] - 2s 197ms/step - loss: 0.0011 - val_loss: 9.1983e-04
# Epoch 61/100
# 11/11 [==============================] - 3s 275ms/step - loss: 9.9701e-04 - val_loss: 6.5862e-04
# Epoch 62/100
# 11/11 [==============================] - 3s 257ms/step - loss: 9.8828e-04 - val_loss: 5.6059e-04
# Epoch 63/100
# 11/11 [==============================] - 2s 192ms/step - loss: 9.8465e-04 - val_loss: 8.6090e-04
# Epoch 64/100
# 11/11 [==============================] - 2s 194ms/step - loss: 9.3243e-04 - val_loss: 5.6274e-04
# Epoch 65/100
# 11/11 [==============================] - 2s 193ms/step - loss: 9.3132e-04 - val_loss: 5.9056e-04
# Epoch 66/100
# 11/11 [==============================] - 2s 195ms/step - loss: 8.9754e-04 - val_loss: 7.5600e-04
# Epoch 67/100
# 11/11 [==============================] - 2s 194ms/step - loss: 8.7753e-04 - val_loss: 7.7701e-04
# Epoch 68/100
# 11/11 [==============================] - 2s 192ms/step - loss: 8.3708e-04 - val_loss: 6.3815e-04
# Epoch 69/100
# 11/11 [==============================] - 2s 195ms/step - loss: 8.3196e-04 - val_loss: 7.4116e-04
# Epoch 70/100
# 11/11 [==============================] - 2s 193ms/step - loss: 8.6239e-04 - val_loss: 5.5738e-04
# Epoch 71/100
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0012 - val_loss: 5.0703e-04
# Epoch 72/100
# 11/11 [==============================] - 2s 193ms/step - loss: 9.7231e-04 - val_loss: 8.0979e-04
# Epoch 73/100
# 11/11 [==============================] - 2s 197ms/step - loss: 0.0010 - val_loss: 4.9659e-04
# Epoch 74/100
# 11/11 [==============================] - 2s 195ms/step - loss: 9.8970e-04 - val_loss: 0.0011
# Epoch 75/100
# 11/11 [==============================] - 2s 199ms/step - loss: 8.8793e-04 - val_loss: 6.0355e-04
# Epoch 76/100
# 11/11 [==============================] - 2s 195ms/step - loss: 8.5774e-04 - val_loss: 4.8579e-04
# Epoch 77/100
# 11/11 [==============================] - 2s 195ms/step - loss: 7.9730e-04 - val_loss: 5.1093e-04
# Epoch 78/100
# 11/11 [==============================] - 2s 196ms/step - loss: 7.9363e-04 - val_loss: 6.8993e-04
# Epoch 79/100
# 11/11 [==============================] - 2s 195ms/step - loss: 7.7314e-04 - val_loss: 6.9183e-04
# Epoch 80/100
# 11/11 [==============================] - 2s 203ms/step - loss: 7.3087e-04 - val_loss: 5.6256e-04
# Epoch 81/100
# 11/11 [==============================] - 2s 197ms/step - loss: 7.5538e-04 - val_loss: 7.9661e-04
# Epoch 82/100
# 11/11 [==============================] - 2s 193ms/step - loss: 8.6995e-04 - val_loss: 4.7687e-04
# Epoch 83/100
# 11/11 [==============================] - 2s 196ms/step - loss: 7.3639e-04 - val_loss: 5.1969e-04
# Epoch 84/100
# 11/11 [==============================] - 2s 195ms/step - loss: 7.4733e-04 - val_loss: 5.4453e-04
# Epoch 85/100
# 11/11 [==============================] - 2s 198ms/step - loss: 8.3093e-04 - val_loss: 7.0805e-04
# Epoch 86/100
# 11/11 [==============================] - 2s 195ms/step - loss: 7.9913e-04 - val_loss: 5.0538e-04
# Epoch 87/100
# 11/11 [==============================] - 2s 194ms/step - loss: 7.5511e-04 - val_loss: 6.2654e-04
# Epoch 88/100
# 11/11 [==============================] - 2s 196ms/step - loss: 7.1323e-04 - val_loss: 6.4597e-04
# Epoch 89/100
# 11/11 [==============================] - 2s 195ms/step - loss: 6.8082e-04 - val_loss: 4.9191e-04
# Epoch 90/100
# 11/11 [==============================] - 2s 198ms/step - loss: 6.9898e-04 - val_loss: 7.0604e-04
# Epoch 91/100
# 11/11 [==============================] - 2s 196ms/step - loss: 7.5449e-04 - val_loss: 4.4810e-04
# Epoch 92/100
# 11/11 [==============================] - 2s 192ms/step - loss: 9.3262e-04 - val_loss: 6.5936e-04
# Epoch 93/100
# 11/11 [==============================] - 2s 193ms/step - loss: 9.1833e-04 - val_loss: 4.3320e-04
# Epoch 94/100
# 11/11 [==============================] - 2s 192ms/step - loss: 8.0882e-04 - val_loss: 9.1400e-04
# Epoch 95/100
# 11/11 [==============================] - 3s 248ms/step - loss: 8.2548e-04 - val_loss: 4.9534e-04
# Epoch 96/100
# 11/11 [==============================] - 2s 194ms/step - loss: 6.3276e-04 - val_loss: 4.1179e-04
# Epoch 97/100
# 11/11 [==============================] - 2s 197ms/step - loss: 6.4619e-04 - val_loss: 6.9884e-04
# Epoch 98/100
# 11/11 [==============================] - 2s 196ms/step - loss: 6.2623e-04 - val_loss: 4.6425e-04
# Epoch 99/100
# 11/11 [==============================] - 2s 194ms/step - loss: 5.9999e-04 - val_loss: 4.1144e-04
# Epoch 100/100
# 11/11 [==============================] - 2s 196ms/step - loss: 6.0536e-04 - val_loss: 4.9407e-04

# %%
import tensorflow as tf

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_test,test_predict))
# Out:
# 0.022227639276708358

# %%
math.sqrt(mean_squared_error(y_test,test_predict))
# Out:
# 151.75860532023492

# %%
look_back=100
trainPredictPlot=numpy.empty_like(df1)
trainPredictPlot[:, :]= np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :]= train_predict

testPredictPlot=numpy.empty_like(df1)
testPredictPlot[:, :]= np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1,:]= test_predict

plt.plot(scaler.inverse_transform(df1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
