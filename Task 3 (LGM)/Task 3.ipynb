# %%
import pandas as pd
from sklearn.metrics import accuracy_score, auc
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
iris = pd.read_csv('/content/drive/MyDrive/LetsGrowMore(task 1)/Iris.csv')

# %% [markdown]
# ## To show First 5 data we use  functiom data.head()

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # *To show Last 5 data we use functiom data.tail()*

# %%
iris.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
iris.head(150)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ## ***what are the columns???. we use the function data.columns()***

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# # *what is the shape of the data?? we use the function data.shape()*

# %%
iris.shape
# Out:
# (150, 6)

# %% [markdown]
# their is the 150 of rows and only 6 *columns*

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# Removing the rows which contains the null values

# %%
iris.dropna(inplace=True)

# %%
iris.shape
# Out:
# (150, 6)

# %% [markdown]
# we see that  their is no null value is present in my dataset

# %% [markdown]
# Label Encoding the non-numeric columns

# %%
from sklearn.preprocessing import LabelEncoder
le  = LabelEncoder()

# %%
iris['Species'] = le.fit_transform(iris['Species'])

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %% [markdown]
# # Here the target variable is species

# %%
dependent_variable = 'Species'

# %%
independent_variables = ['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']

# %%
X = iris[independent_variables]

# %%
y = iris[dependent_variable]

# %% [markdown]
# By using train_test_split we have split the data into traing dataset and testing datasets.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=324)

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier( max_depth = 4, max_features=2)
model.fit( X_train, y_train )
# Out:
# DecisionTreeClassifier(max_depth=4, max_features=2)

# %%
model.fit( X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, max_features=2)

# %% [markdown]
# Fit on Train Set

# %%
humidity_classifier = DecisionTreeClassifier(criterion='entropy', max_leaf_nodes=10, random_state=0)
humidity_classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_leaf_nodes=10, random_state=0)

# %% [markdown]
# Predict on Test Set

# %%
y_predicted = humidity_classifier.predict(X_test)

# %%
y_predicted[:10]
# Out:
# array([0, 1, 2, 0, 2, 1, 1, 0, 1, 2])

# %%
y_test[:10]
# Out:
# 11     0
# 106    2
# 102    2
# 10     0
# 126    2
# 65     1
# 57     1
# 31     0
# 67     1
# 145    2
# Name: Species, dtype: int64

# %% [markdown]
# Measure Accuracy of the Classifier

# %%
accuracy_score(y_test, y_predicted) * 100
# Out:
# 98.0

# %%
iris.iloc[-1]
# Out:
# Id               150.0
# SepalLengthCm      5.9
# SepalWidthCm       3.0
# PetalLengthCm      5.1
# PetalWidthCm       1.8
# Species            2.0
# Name: 149, dtype: float64

# %%
from sklearn import preprocessing
min_max = preprocessing.MinMaxScaler()
iris_df = min_max.fit_transform(X.values)

# %%
iris_df
# Out:
# array([[0.22222222, 0.625     , 0.06779661, 0.04166667],
#        [0.16666667, 0.41666667, 0.06779661, 0.04166667],
#        [0.11111111, 0.5       , 0.05084746, 0.04166667],
#        [0.08333333, 0.45833333, 0.08474576, 0.04166667],
#        [0.19444444, 0.66666667, 0.06779661, 0.04166667],
#        [0.30555556, 0.79166667, 0.11864407, 0.125     ],
#        [0.08333333, 0.58333333, 0.06779661, 0.08333333],
#        [0.19444444, 0.58333333, 0.08474576, 0.04166667],
#        [0.02777778, 0.375     , 0.06779661, 0.04166667],
#        [0.16666667, 0.45833333, 0.08474576, 0.        ],
#        [0.30555556, 0.70833333, 0.08474576, 0.04166667],
#        [0.13888889, 0.58333333, 0.10169492, 0.04166667],
#        [0.13888889, 0.41666667, 0.06779661, 0.        ],
#        [0.        , 0.41666667, 0.01694915, 0.        ],
#        [0.41666667, 0.83333333, 0.03389831, 0.04166667],
#        [0.38888889, 1.        , 0.08474576, 0.125     ],
# ...

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_predicted)
cm
# Out:
# array([[16,  0,  0],
#        [ 0, 17,  0],
#        [ 0,  1, 16]])

# %%
import seaborn as sb
plt.figure(figsize=(6,4))
sb.heatmap(cm,annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(33.0, 0.5, 'Truth')

# %%
import sklearn.metrics as metrics

# %%
print('Confusion matrix \n')
print(metrics.confusion_matrix(y_test,y_predicted))
print('*'*80)
print('\n')
print('Classification report \n')
print(metrics.classification_report(y_test,y_predicted))
# Out:
# Confusion matrix
#
# [[16  0  0]
#  [ 0 17  0]
#  [ 0  1 16]]
# ********************************************************************************
#
#
# Classification report
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       0.94      1.00      0.97        17
#            2       1.00      0.94      0.97        17
#
#     accuracy                           0.98        50
#    macro avg       0.98      0.98      0.98        50
# weighted avg       0.98      0.98      0.98        50

# %% [markdown]
# # *Visulaizing Decision Tree*

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import tree
from IPython.display import SVG
from graphviz import Source
from IPython.display import display

# %%
model=DecisionTreeClassifier()

# %%
from sklearn import tree
fn=['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)']
cn=['setosa', 'versicolor', 'virginica']
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (15,10), dpi=300)
tree.plot_tree(model,
               feature_names = fn, 
               class_names=cn,
               filled = True);
fig.savefig('imagename.png')
